# %% [markdown]
# <a href="https://colab.research.google.com/github/26413-lgtm/10713/blob/main/2026903.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("안녕하세요?")
print("반갑습니다.")
print("저는 이동주입니다.")
# Out:
# 안녕하세요?
# 반갑습니다.
# 저는 이동주입니다.

# %%
print('재미있는 프로그래밍')
print(3 + 7)
print('3 + 7')
print(10, 20, 30, '정보', '프로그래밍')
# Out:
# 재미있는 프로그래밍
# 10
# 3 + 7
# 10 20 30 정보 프로그래밍

# %%
a = 20
b = 50
print('현재 온도는 %d도, 습도는 %d%% 입니다.' %(a, b))
# Out:
# 현재 온도는 20도, 습도는 50% 입니다.

# %%
c=90
d=3.141592
print(f'직각은 {c}도, 원주율은 {d:0.2f}입니다.')
# Out:
# 직각은 90도, 원주율은 3.14입니다.
