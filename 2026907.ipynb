# %% [markdown]
# <a href="https://colab.research.google.com/github/26413-lgtm/10713/blob/main/2026907.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datetime
from datetime import datetime, date, time

# %%
print('디데이(D-day) 프로그램>')
print()
year = int(input('연도를 입려하세요:'))
month = int(input('월을 입력하세요:'))
day = int(input('일을 입력하세요:'))
dt4 = date(year, month, day)
today = date.today()
dday = (dt4 - today).days
print(f'{year}년 {month}월 {day}일은 {dday}일 남았습니다.')
# Out:
# 디데이(D-day) 프로그램>
#
# 연도를 입려하세요:2027
# 월을 입력하세요:10
# 일을 입력하세요:10
# 2027년 10월 10일은 398일 남았습니다.
