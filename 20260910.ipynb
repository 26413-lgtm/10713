# %% [markdown]
# <a href="https://colab.research.google.com/github/26413-lgtm/10713/blob/main/20260910.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 'hello'
b = 'world'
print(a + b)
print(a * 3)
print(a < b)
print('h' in a)
print('wor' not in b)
# Out:
# hello world
# hello hello hello
# True
# True
# False

# %%
a = 'Hello python'
print(a[0])
print(a[6])
print(a[-1])
# Out:
# H
# p
# n

# %%
a = 'hello python'
print(a[0:5])
print(a[6:])
print(a[:5])
print(a[6:-4])
print(a[0:9:2])
# Out:
# hello
# python
# hello
# py
# hlopt

# %%
a = '100521'

print('연 : 20' + a[0 : 2] + '년')
print('월 : ' +a[2 : 4] + '월')
print('일 : ' + a[4 : 7] + '일')
# Out:
# 연 : 2010년
# 월 : 05월
# 일 : 21일

# %%
|
